# %% [markdown]
# Loading the dataset

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('car data.csv')

# %%
df1.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# Data Cleaning

# %%
if df1.isnull().sum().empty == False:
    print('No null records in dataset')
# Out:
# No null records in dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
# Car_Name         301 non-null object
# Year             301 non-null int64
# Selling_Price    301 non-null float64
# Present_Price    301 non-null float64
# Kms_Driven       301 non-null int64
# Fuel_Type        301 non-null object
# Seller_Type      301 non-null object
# Transmission     301 non-null object
# Owner            301 non-null int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 16.5+ KB

# %%
# Number of unique values in each column
for column in df1[['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]:
    print('Unique categories in', column, ':', df1[column].nunique())
# Out:
# Unique categories in Car_Name : 98
# Unique categories in Year : 16
# Unique categories in Selling_Price : 156
# Unique categories in Present_Price : 147
# Unique categories in Kms_Driven : 206
# Unique categories in Fuel_Type : 3
# Unique categories in Seller_Type : 2
# Unique categories in Transmission : 2
# Unique categories in Owner : 3

# %%
# current year-year in which the car was bought
df1['no_years'] = 2020 - df1['Year']
df1.drop('Year', axis=1, inplace = True)
df1.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz           3.35           5.59       27000    Petrol      Dealer
# 1      sx4           4.75           9.54       43000    Diesel      Dealer
# 2     ciaz           7.25           9.85        6900    Petrol      Dealer
# 3  wagon r           2.85           4.15        5200    Petrol      Dealer
# 4    swift           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_years
# 0       Manual      0         6
# 1       Manual      0         7
# 2       Manual      0         3
# 3       Manual      0         9
# 4       Manual      0         6

# %%
df1
# Out:
#     Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0       ritz           3.35           5.59       27000    Petrol      Dealer
# 1        sx4           4.75           9.54       43000    Diesel      Dealer
# 2       ciaz           7.25           9.85        6900    Petrol      Dealer
# 3    wagon r           2.85           4.15        5200    Petrol      Dealer
# 4      swift           4.60           6.87       42450    Diesel      Dealer
# ..       ...            ...            ...         ...       ...         ...
# 296     city           9.50          11.60       33988    Diesel      Dealer
# 297     brio           4.00           5.90       60000    Petrol      Dealer
# 298     city           3.35          11.00       87934    Petrol      Dealer
# 299     city          11.50          12.50        9000    Diesel      Dealer
# 300     brio           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  no_years
# 0         Manual      0         6
# 1         Manual      0         7
# 2         Manual      0         3
# 3         Manual      0         9
# 4         Manual      0         6
# ..           ...    ...       ...
# 296       Manual      0         4
# 297       Manual      0         5
# 298       Manual      0        11
# 299       Manual      0         3
# 300       Manual      0         4
#
# [301 rows x 9 columns]

# %%
# Convert categorical variable into indicator variables
def encode(df):
    for column in df.columns[df.columns.isin(['Car_Name', 'Fuel_Type', 'Seller_Type', 'Transmission'])]:
        df[column] = df[column].factorize()[0]
    return df
df_enc = encode(df1)
df_enc
# Out:
#      Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0           0           3.35           5.59       27000          0
# 1           1           4.75           9.54       43000          1
# 2           2           7.25           9.85        6900          0
# 3           3           2.85           4.15        5200          0
# 4           4           4.60           6.87       42450          1
# ..        ...            ...            ...         ...        ...
# 296        94           9.50          11.60       33988          1
# 297        95           4.00           5.90       60000          0
# 298        94           3.35          11.00       87934          0
# 299        94          11.50          12.50        9000          1
# 300        95           5.30           5.90        5464          0
#
#      Seller_Type  Transmission  Owner  no_years
# 0              0             0      0         6
# 1              0             0      0         7
# 2              0             0      0         3
# 3              0             0      0         9
# 4              0             0      0         6
# ..           ...           ...    ...       ...
# 296            0             0      0         4
# 297            0             0      0         5
# 298            0             0      0        11
# 299            0             0      0         3
# 300            0             0      0         4
#
# [301 rows x 9 columns]

# %%
#get correlations of each features in dataset
corr = df_enc.corr()['Selling_Price'].to_frame().abs().sort_values(ascending=False, by='Selling_Price').style.background_gradient()
corr
# Out:
# <style  type="text/css" >
#     #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow1_col0 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow2_col0 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow3_col0 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow4_col0 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow5_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow6_col0 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow7_col0 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Selling_Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row0" class="row_heading level0 row0" >Selling_Price</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow0_col0" class="data row0 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row1" class="row_heading level0 row1" >Present_Price</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow1_col0" class="data row1 col0" >0.878983</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row2" class="row_heading level0 row2" >Seller_Type</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow2_col0" class="data row2 col0" >0.550724</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row3" class="row_heading level0 row3" >Fuel_Type</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow3_col0" class="data row3 col0" >0.509467</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row4" class="row_heading level0 row4" >Transmission</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow4_col0" class="data row4 col0" >0.367128</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row5" class="row_heading level0 row5" >no_years</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow5_col0" class="data row5 col0" >0.236141</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row6" class="row_heading level0 row6" >Car_Name</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow6_col0" class="data row6 col0" >0.102556</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row7" class="row_heading level0 row7" >Owner</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow7_col0" class="data row7 col0" >0.0883441</td>
#             </tr>
#             <tr>
#                         <th id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76alevel0_row8" class="row_heading level0 row8" >Kms_Driven</th>
#                         <td id="T_1bc8b9da_ba41_11ec_8f46_74dfbf67a76arow8_col0" class="data row8 col0" >0.0291871</td>
#             </tr>
#     </tbody></table>

# %%
df_enc.corr()['Selling_Price'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_enc.columns
# Out:
# Index(['Car_Name', 'Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'no_years'],
#       dtype='object')

# %%
# Re-arranging columns so as to make 'Selling_Price' the first column
# This avoids the error "DataConversionWarning: A column-vector y was passed when a 1d array was expected" while training
df = df_enc[['Selling_Price', 'Car_Name', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
       'Seller_Type', 'Transmission', 'Owner', 'no_years']]

# %%
df
# Out:
#      Selling_Price  Car_Name  Present_Price  Kms_Driven  Fuel_Type  \
# 0             3.35         0           5.59       27000          0
# 1             4.75         1           9.54       43000          1
# 2             7.25         2           9.85        6900          0
# 3             2.85         3           4.15        5200          0
# 4             4.60         4           6.87       42450          1
# ..             ...       ...            ...         ...        ...
# 296           9.50        94          11.60       33988          1
# 297           4.00        95           5.90       60000          0
# 298           3.35        94          11.00       87934          0
# 299          11.50        94          12.50        9000          1
# 300           5.30        95           5.90        5464          0
#
#      Seller_Type  Transmission  Owner  no_years
# 0              0             0      0         6
# 1              0             0      0         7
# 2              0             0      0         3
# 3              0             0      0         9
# 4              0             0      0         6
# ..           ...           ...    ...       ...
# 296            0             0      0         4
# 297            0             0      0         5
# 298            0             0      0        11
# 299            0             0      0         3
# 300            0             0      0         4
#
# [301 rows x 9 columns]

# %%
X=df.drop(['Selling_Price'], axis=1)
y=df.iloc[:,0]

# %%
X
# Out:
#      Car_Name  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0           0           5.59       27000          0            0
# 1           1           9.54       43000          1            0
# 2           2           9.85        6900          0            0
# 3           3           4.15        5200          0            0
# 4           4           6.87       42450          1            0
# ..        ...            ...         ...        ...          ...
# 296        94          11.60       33988          1            0
# 297        95           5.90       60000          0            0
# 298        94          11.00       87934          0            0
# 299        94          12.50        9000          1            0
# 300        95           5.90        5464          0            0
#
#      Transmission  Owner  no_years
# 0               0      0         6
# 1               0      0         7
# 2               0      0         3
# 3               0      0         9
# 4               0      0         6
# ..            ...    ...       ...
# 296             0      0         4
# 297             0      0         5
# 298             0      0        11
# 299             0      0         3
# 300             0      0         4
#
# [301 rows x 8 columns]

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()

# %%
# Hyperparameter optimization or tuning
from sklearn.model_selection import RandomizedSearchCV

# %%
# Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 600, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 145, 190, 236, 281, 327, 372, 418, 463, 509, 554, 600], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use the random grid to search for best hyperparameters
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
regressor_random = RandomizedSearchCV(estimator = regressor, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, n_jobs = 1)

# %%
regressor_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=281; total time=   1.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=281; total time=   1.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=281; total time=   0.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=281; total time=   0.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=281; total time=   1.0s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=418; total time=   1.4s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=418; total time=   1.5s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=418; total time=   1.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=418; total time=   1.5s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=1, min_samples_split=15, n_estimators=418; total time=   1.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=372; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=372; total time=   0.7s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=372; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=372; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=372; total time=   0.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=327; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=327; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=327; total time=   0.6s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=327; total time=   0.7s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=327; total time=   0.6s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=418; total time=   0.8s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=418; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=418; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=418; total time=   0.9s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=418; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=418; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=418; total time=   1.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=418; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=418; total time=   1.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=418; total time=   1.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=372; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=372; total time=   0.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=372; total time=   0.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=372; total time=   0.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=372; total time=   1.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=463; total time=   0.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=463; total time=   1.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=463; total time=   1.7s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=463; total time=   1.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=463; total time=   1.7s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=418; total time=   1.2s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=418; total time=   1.2s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=418; total time=   1.1s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=418; total time=   1.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=418; total time=   1.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=418; total time=   1.3s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=418; total time=   1.6s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=418; total time=   1.2s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=418; total time=   1.0s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=418; total time=   1.0s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 145, 190, 236,
#                                                          281, 327, 372, 418,
#                                                          463, 509, 554, 600]},
#                    scoring='neg_mean_squared_error', verbose=2)

# %%
# Prediction
predictions=regressor_random.predict(X_test)

# %%
plt.figure(figsize=(8,6))
sns.distplot(y_test-predictions)
# Out:
# <AxesSubplot:xlabel='Selling_Price'>

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

from sklearn.metrics import r2_score
r2_score(y_test,predictions)
# Out:
# 0.6672335511628467

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 1.2418371658773855
# MSE: 10.174279755574295
# RMSE: 3.189714682471505

# %%
# Saving model to disk
import pickle
# Open a file to store the data
file = open('regressor_random_new.pkl', 'wb')

# dump information to that file
pickle.dump(regressor_random, file)
